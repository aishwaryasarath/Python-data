# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryasarath/Python-data/blob/main/Astronauts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import pandas as pd
import numpy as np
filename = "/content/sample_data/astronauts.csv"
df = pd.read_csv(filename)
df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
df.tail(5)
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 352   Indianapolis, IN   Male
# 353        Chicago, IL   Male
# 354        Jackson, MI   Male
# 355  San Francisco, CA   Male
# 356    Jersey City, NJ   Male
#
#                                             Alma Mater  \
# 352              Purdue University; Indiana University
# 353  MIT; University of Texas-Austin; George Washin...
# 354        US Military Academy; University of Michigan
# 355                    Georgia Institute of Technology
# 356  US Naval Academy; Florida Institute of Technology
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=357, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Year', 'Group', 'Status', 'Birth Date', 'Birth Place',
#        'Gender', 'Alma Mater', 'Undergraduate Major', 'Graduate Major',
#        'Military Rank', 'Military Branch', 'Space Flights',
#        'Space Flight (hr)', 'Space Walks', 'Space Walks (hr)', 'Missions',
#        'Death Date', 'Death Mission'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name                    object
# Year                   float64
# Group                  float64
# Status                  object
# Birth Date              object
# Birth Place             object
# Gender                  object
# Alma Mater              object
# Undergraduate Major     object
# Graduate Major          object
# Military Rank           object
# Military Branch         object
# Space Flights            int64
# Space Flight (hr)        int64
# Space Walks              int64
# Space Walks (hr)       float64
# Missions                object
# Death Date              object
# Death Mission           object
# dtype: object

# %%
df.values
# Out:
# array([['Joseph M. Acaba', 2004.0, 19.0, ...,
#         'STS-119 (Discovery), ISS-31/32 (Soyuz)', nan, nan],
#        ['Loren W. Acton', nan, nan, ..., 'STS 51-F (Challenger)', nan,
#         nan],
#        ['James C. Adamson', 1984.0, 10.0, ...,
#         'STS-28 (Columbia), STS-43 (Atlantis)', nan, nan],
#        ...,
#        ['Alfred M. Worden', 1966.0, 5.0, ..., 'Apollo 15', nan, nan],
#        ['John W. Young', 1962.0, 2.0, ...,
#         'Gemini 3, Gemini 10, Apollo 10, Apollo 16, STS-1 (Columbia), STS-9 (Columbia)',
#         nan, nan],
#        ['George D. Zamka', 1998.0, 17.0, ...,
#         'STS-120 (Discovery), STS-130 (Endeavor)', nan, nan]],
#       dtype=object)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# ...

# %%
df.Name
# Out:
# 0            Joseph M. Acaba
# 1             Loren W. Acton
# 2           James C. Adamson
# 3            Thomas D. Akers
# 4                Buzz Aldrin
#                ...
# 352            David A. Wolf
# 353    Neil W. Woodward III
# 354         Alfred M. Worden
# 355            John W. Young
# 356          George D. Zamka
# Name: Name, Length: 357, dtype: object

# %%
df[2:4]
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
#
#                                   Alma Mater  Undergraduate Major  \
# 2  US Military Academy; Princeton University          Engineering
# 3               University of Missouri-Rolla  Applied Mathematics
#
#           Graduate Major Military Rank         Military Branch  Space Flights  \
# 2  Aerospace Engineering       Colonel       US Army (Retired)              2
# 3    Applied Mathematics       Colonel  US Air Force (Retired)              4
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 2                334            0               0.0
# 3                814            4              29.0
#
#                                             Missions Death Date Death Mission
# ...

# %%
df[['Name','Status']].head()
# Out:
#                Name   Status
# 0   Joseph M. Acaba   Active
# 1    Loren W. Acton  Retired
# 2  James C. Adamson  Retired
# 3   Thomas D. Akers  Retired
# 4       Buzz Aldrin  Retired

# %%
df.loc[3:7,['Name','Status']]
# Out:
#               Name   Status
# 3  Thomas D. Akers  Retired
# 4      Buzz Aldrin  Retired
# 5  Andrew M. Allen  Retired
# 6  Joseph P. Allen  Retired
# 7  Scott D. Altman  Retired

# %%
df.iloc[3:7,[0,3]]
# Out:
#               Name   Status
# 3  Thomas D. Akers  Retired
# 4      Buzz Aldrin  Retired
# 5  Andrew M. Allen  Retired
# 6  Joseph P. Allen  Retired

# %%
df[df.Year > 1984.0].head()
# Out:
#                   Name    Year  Group   Status Birth Date       Birth Place  \
# 0      Joseph M. Acaba  2004.0   19.0   Active  5/17/1967     Inglewood, CA
# 3      Thomas D. Akers  1987.0   12.0  Retired  5/20/1951     St. Louis, MO
# 5      Andrew M. Allen  1987.0   12.0  Retired   8/4/1955  Philadelphia, PA
# 7      Scott D. Altman  1995.0   15.0  Retired  8/15/1959       Lincoln, IL
# 9  Clayton C. Anderson  1998.0   17.0  Retired  2/23/1959         Omaha, NE
#
#   Gender                                         Alma Mater  \
# 0   Male  University of California-Santa Barbara; Univer...
# 3   Male                       University of Missouri-Rolla
# 5   Male        Villanova University; University of Florida
# 7   Male  University of Illinois; US Naval Postgraduate ...
# 9   Male            Hastings College; Iowa State University
#
#                         Undergraduate Major            Graduate Major  \
# 0                                   Geology                   Geology
# ...

# %%
df[df['Year'].isin([1995.0,1998.0])].head(5)
# Out:
#                    Name    Year  Group    Status  Birth Date      Birth Place  \
# 7       Scott D. Altman  1995.0   15.0   Retired   8/15/1959      Lincoln, IL
# 9   Clayton C. Anderson  1998.0   17.0   Retired   2/23/1959        Omaha, NE
# 10  Michael P. Anderson  1995.0   15.0  Deceased  12/25/1959  Plattsburgh, NY
# 13   Lee J. Archambault  1998.0   17.0   Retired   8/25/1960     Oak Park, IL
# 16     Jeffrey S. Ashby  1995.0   15.0   Retired    6/1/1954       Dallas, TX
#
#    Gender                                         Alma Mater  \
# 7    Male  University of Illinois; US Naval Postgraduate ...
# 9    Male            Hastings College; Iowa State University
# 10   Male     University of Washington; Creighton University
# 13   Male                      University of Illinois-Urbana
# 16   Male       University of Idaho; University of Tennessee
#
#                          Undergraduate Major  \
# 7   Aeronautical & Astronautical Engineering
# ...

# %%
df['Space Walks (min)'] = df['Space Walks (hr)']*60
df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
df = df.rename(columns = {'Status':'status'})
df.head()
# Out:
#                Name    Year  Group   status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
#df2 = df.set_index("id")
#df2.head()

# %%
df3 = df.groupby("Military Rank").mean()
df3.head()
# Out:
#                               Year      Group  Space Flights  \
# Military Rank
# Brigadier General      1978.750000   6.750000       2.000000
# Captain                1983.925373  10.940299       2.647059
# Chief Warrant Officer          NaN        NaN       1.000000
# Colonel                1985.526882  11.526882       2.638298
# Commander              1994.692308  15.153846       1.230769
#
#                        Space Flight (hr)  Space Walks  Space Walks (hr)
# Military Rank
# Brigadier General             398.000000     1.250000          8.000000
# Captain                      1427.117647     1.220588          7.433824
# Chief Warrant Officer         166.000000     0.000000          0.000000
# Colonel                      1397.414894     1.148936          7.015957
# Commander                     891.923077     1.076923          6.230769

# %%
df3.reset_index(drop=True)
# Out:
#            Year      Group  Space Flights  Space Flight (hr)  Space Walks  \
# 0   1978.750000   6.750000       2.000000         398.000000     1.250000
# 1   1983.925373  10.940299       2.647059        1427.117647     1.220588
# 2           NaN        NaN       1.000000         166.000000     0.000000
# 3   1985.526882  11.526882       2.638298        1397.414894     1.148936
# 4   1994.692308  15.153846       1.230769         891.923077     1.076923
# 5   1983.700000  10.600000       2.100000         406.400000     0.500000
# 6   1978.333333   8.666667       1.333333         183.666667     0.000000
# 7   1976.000000   7.500000       4.500000        2785.000000     0.500000
# 8   1966.500000   4.250000       0.800000          91.400000     0.000000
# 9   1972.250000   6.500000       2.000000         310.250000     0.000000
# 10  1962.500000   3.000000       2.500000         362.000000     1.500000
# 11  1969.000000   7.000000       2.000000         199.000000     0.000000
#
# ...

# %%
df3.sort_index(ascending=False).head(2)
# Out:
#                  Year  Group  Space Flights  Space Flight (hr)  Space Walks  \
# Military Rank
# Vice Admiral   1969.0    7.0            2.0              199.0          0.0
# Rear Admiral   1962.5    3.0            2.5              362.0          1.5
#
#                Space Walks (hr)
# Military Rank
# Vice Admiral                0.0
# Rear Admiral                5.0

# %%
df.sort_values(["Space Flights", "Space Walks"]).head(2)
# Out:
#                       Name    Year  Group    Status  Birth Date  \
# 17         Serena M. Aunon  2009.0   20.0    Active    4/9/1976
# 24  Charles A. Bassett II   1963.0    3.0  Deceased  12/30/1931
#
#          Birth Place  Gender  \
# 17  Indianapolis, IN  Female
# 24        Dayton, OH    Male
#
#                                            Alma Mater     Undergraduate Major  \
# 17  George Washington University; University of Texas  Electrical Engineering
# 24                        Texas Technological College  Electrical Engineering
#
#    Graduate Major Military Rank Military Branch  Space Flights  \
# 17       Medicine           NaN             NaN              0
# 24            NaN       Captain    US Air Force              0
#
#     Space Flight (hr)  Space Walks  Space Walks (hr) Missions Death Date  \
# 17                  0            0               0.0      NaN        NaN
# 24                  0            0               0.0      NaN  2/28/1966
#
# ...

# %%
df.Status.unique()
# Out:
# array(['Active', 'Retired', 'Deceased', 'Management'], dtype=object)

# %%
df = df.rename(columns = {'Undergraduate Major':'Undergraduate_Major'})
df.head(2)
# Out:
#               Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1   Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
#
#                                           Alma Mater  Undergraduate_Major  \
# 0  University of California-Santa Barbara; Univer...              Geology
# 1   Montana State University; University of Colorado  Engineering Physics
#
#   Graduate Major Military Rank Military Branch  Space Flights  \
# 0        Geology           NaN             NaN              2
# 1  Solar Physics           NaN             NaN              1
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
#
#                                  Missions Death Date Death Mission  \
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN
# ...

# %%
df.Undergraduate_Major.unique()
# Out:
# array(['Geology', 'Engineering Physics', 'Engineering',
#        'Applied Mathematics', 'Mechanical Engineering',
#        'Mathematics & Physics',
#        'Aeronautical & Astronautical Engineering', 'Nuclear Engineering',
#        'Physics', 'Physics & Astronomy', 'Aeronautics & Astronautics',
#        'Aeronautical Engineering', 'Accounting', 'Electrical Engineering',
#        'Aerospace Engineering', 'Zoology',
#        'Physics & Mechanical Engineering', 'Engineering Science',
#        'Engineering Mechanics', nan, 'Electrical Science',
#        'Business Management; Aeronautical Engineering', 'Mathematics',
#        'Biology', 'Biochemistry', 'Chemistry',
#        'Aerospace Engineering & Mechanics', 'Physics & Mathematics',
#        'Chemical Engineering', 'Biological Science',
#        'Mathematics & Economics',
#        'Applied Biology; Mechanical Engineering',
#        'Chemistry; Physiological Optics',
#        'Physics & Astronautical Engineering', 'Naval Sciences',
# ...

# %%
df.Undergraduate_Major.value_counts()
# Out:
# Physics                                  35
# Aerospace Engineering                    33
# Mechanical Engineering                   30
# Aeronautical Engineering                 28
# Electrical Engineering                   23
#                                          ..
# Astronomy                                 1
# Marine Engineering & Nautical Science     1
# Philosophy                                1
# Bioscience                                1
# Military Science                          1
# Name: Undergraduate_Major, Length: 83, dtype: int64

# %%
df.sort_values(["Space Flights", "Space Walks"], ascending=[False, True]).head(2)
# Out:
#                        Name    Year  Group   Status Birth Date  \
# 65   Franklin R. Chang-Diaz  1980.0    9.0  Retired   4/5/1950
# 279           Jerry L. Ross  1980.0    9.0  Retired  1/20/1948
#
#               Birth Place Gender                      Alma Mater  \
# 65   San Jose, Costa Rica   Male  University of Connecticut; MIT
# 279       Crown Point, IN   Male               Purdue University
#
#         Undergraduate_Major          Graduate Major Military Rank  \
# 65   Mechanical Engineering  Applied Plasma Physics           NaN
# 279  Mechanical Engineering  Mechanical Engineering       Colonel
#
#             Military Branch  Space Flights  Space Flight (hr)  Space Walks  \
# 65                      NaN              7               1602            3
# 279  US Air Force (Retired)              7               1393            9
#
#      Space Walks (hr)                                           Missions  \
# ...

# %%
#RANK - like sorting but with collision detection
dfp = df.sort_values("Space_Flight_(hr)", ascending = False)
dfp[["Name", "Birth Date", "Space_Flight_(hr)"]].head(4)
# Out:
#                     Name Birth Date  Space_Flight_(hr)
# 346  Jeffrey N. Williams  1/18/1958              12818
# 183       Scott J. Kelly  2/21/1964              12490
# 342     Peggy A. Whitson   2/9/1960              11698
# 107    E. Michael Fincke  3/14/1967               9159

# %%
df = df.rename(columns = {'Space Flight (hr)':'Space_Flight_(hr)'})
df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate_Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...
