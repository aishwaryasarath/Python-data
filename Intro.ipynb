# %%
import numpy as np
import pandas as pd

filename = "heart.csv"
df = pd.read_csv(filename)
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.tail(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.sort_values('chol', ascending=False)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 85    67    0   2       115   564    0        0      160      0      1.6
# 28    65    0   2       140   417    1        0      157      0      0.8
# 246   56    0   0       134   409    0        0      150      1      1.9
# 220   63    0   0       150   407    0        0      154      0      4.0
# 96    62    0   0       140   394    0        0      157      0      1.2
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 267   49    1   2       118   149    0        0      126      0      0.8
# 151   71    0   0       112   149    0        1      125      0      1.6
# 53    44    0   2       108   141    0        1      175      0      0.6
# 301   57    1   0       130   131    0        1      115      1      1.2
# 111   57    1   2       150   126    1        1      173      0      0.2
#
#      slope  ca  thal  target
# 85       1   0     3       1
# 28       2   1     2       1
# ...

# %%
#to get just one column
df.age
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
# to get just one column
df['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
#rows 2 to 3
df[2:4]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
#
#    ca  thal  target
# 2   0     2       1
# 3   0     2       1

# %%
# to get multiple columns
df[['age','chol']]
# Out:
#      age  chol
# 0     63   233
# 1     37   250
# 2     41   204
# 3     56   236
# 4     57   354
# ..   ...   ...
# 298   57   241
# 299   45   264
# 300   68   193
# 301   57   131
# 302   57   236
#
# [303 rows x 2 columns]

# %%
#df.loc[from_row:to_row,['col1','col2']]
df.loc[:,['age','sex']] #all rows, specific col
# Out:
#      age  sex
# 0     63    1
# 1     37    1
# 2     41    0
# 3     56    1
# 4     57    0
# ..   ...  ...
# 298   57    0
# 299   45    1
# 300   68    1
# 301   57    1
# 302   57    0
#
# [303 rows x 2 columns]

# %%
df.loc[9,['age']]
# Out:
# age    57.0
# Name: 9, dtype: float64

# %%
df.iloc[3:5,[0,3]]
# Out:
#    age  trestbps
# 3   56       120
# 4   57       120

# %%
df[df.age>60] # filtering
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 13    64    1   3       110   211    0        0      144      1      1.8
# 17    66    0   3       150   226    0        1      114      0      2.6
# 19    69    0   3       140   239    0        1      151      0      1.8
# 23    61    1   2       150   243    1        1      137      1      1.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 290   61    1   0       148   203    0        1      161      0      0.0
# 293   67    1   2       152   212    0        0      150      0      0.8
# 295   63    1   0       140   187    0        0      144      1      4.0
# 296   63    0   0       124   197    0        1      136      1      0.0
# 300   68    1   0       144   193    1        1      141      0      3.4
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 13       1   0     2       1
# ...

# %%
df[df['age'].isin([63,61,68])]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 23    61    1   2       150   243    1        1      137      1      1.0
# 54    63    0   2       135   252    0        0      172      0      0.0
# 86    68    1   2       118   277    0        1      151      0      1.0
# 102   63    0   1       140   195    0        1      179      0      0.0
# 105   68    0   2       120   211    0        0      115      0      1.5
# 168   63    1   0       130   254    0        0      147      0      1.4
# 182   61    0   0       130   330    0        0      169      0      0.0
# 203   68    1   2       180   274    1        0      150      1      1.6
# 211   61    1   0       120   260    0        1      140      1      3.6
# 213   61    0   0       145   307    0        0      146      1      1.0
# 217   63    1   0       130   330    1        0      132      1      1.8
# ...

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3         5   233    1        0      150      0      2.3
# 1     37    1   2         5   250    0        1      187      0      3.5
# 2     44    0   1         5   204    0        0      172      0      1.4
# 3     56    1   1         5   236    0        1      178      0      0.8
# 4     57    0   0         5   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0         5   241    0        1      123      1      0.2
# 299   45    1   3         5   264    0        1      132      0      1.2
# 300   68    1   0         5   193    1        1      141      0      3.4
# 301   57    1   0         5   131    0        1      115      1      1.2
# 302   57    0   1         5   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  new_col
# 0        0   0     1       1      0.0
# ...

# %%
df.loc[2,['age']]=44 # assignment
df.iloc[2:4]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 2   44    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
#
#    ca  thal  target
# 2   0     2       1
# 3   0     2       1

# %%
# nan not a number
# df.loc[2, ['age']] = np.nan

# %%
df.loc[:,'chol'] = np.array([5] * len(df))
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3         5     5    1        0      150      0      2.3      0
# 1   37    1   2         5     5    0        1      187      0      3.5      0
# 2   44    0   1         5     5    0        0      172      0      1.4      2
# 3   56    1   1         5     5    0        1      178      0      0.8      2
# 4   57    0   0         5     5    0        1      163      1      0.6      2
#
#    ca  thal  target  new_col
# 0   0     1       1      0.0
# 1   0     2       1      0.0
# 2   0     2       1      1.0
# 3   0     2       1      1.0
# 4   0     2       1      1.0

# %%
df['new_col'] = (df.slope + df.ca)/2
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3         5     5    1        0      150      0      2.3      0
# 1   37    1   2         5     5    0        1      187      0      3.5      0
# 2   44    0   1         5     5    0        0      172      0      1.4      2
# 3   56    1   1         5     5    0        1      178      0      0.8      2
# 4   57    0   0         5     5    0        1      163      1      0.6      2
#
#    ca  thal  target  new_col
# 0   0     1       1      0.0
# 1   0     2       1      0.0
# 2   0     2       1      1.0
# 3   0     2       1      1.0
# 4   0     2       1      1.0

# %%
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3         5   233    1        0      150      0      2.3
# 1     37    1   2         5   250    0        1      187      0      3.5
# 2     44    0   1         5   204    0        0      172      0      1.4
# 3     56    1   1         5   236    0        1      178      0      0.8
# 4     57    0   0         5   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0         5   241    0        1      123      1      0.2
# 299   45    1   3         5   264    0        1      132      0      1.2
# 300   68    1   0         5   193    1        1      141      0      3.4
# 301   57    1   0         5   131    0        1      115      1      1.2
# 302   57    0   1         5   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  new_col
# 0        0   0     1       1      0.0
# ...

# %%
df.rename(columns = {'age':'Age'}, inplace=True)
          # or df = df.rename(columns = {'age':'Age'}
df.head()
# Out:
#    Age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3         5     5    1        0      150      0      2.3      0
# 1   37    1   2         5     5    0        1      187      0      3.5      0
# 2   44    0   1         5     5    0        0      172      0      1.4      2
# 3   56    1   1         5     5    0        1      178      0      0.8      2
# 4   57    0   0         5     5    0        1      163      1      0.6      2
#
#    ca  thal  target  new_col
# 0   0     1       1      0.0
# 1   0     2       1      0.0
# 2   0     2       1      1.0
# 3   0     2       1      1.0
# 4   0     2       1      1.0

# %%
#df.columns = [ all new column names here in single quotes]

# %%
for index, row in df.iterrows():
    print(index, row["age"], row["sex"])

# %%
df.to_csv('foo.csv')

# %%
ls
# Out:
# 1_loading.ipynb        heart.csv              leetcode2.py
# 2. numpv-pandas.ipynb  heart.pkl              leetcode3.py
# Intro.ipynb            jupyter-1.0.0/         untitled
# Untitled.ipynb         jupyter.tar.gz
# foo.csv                leetcode-two-sum.py

# %%
cat foo.csv
# Out:
# ,Age,sex,cp,trestbps,chol,fbs,restecg,thalach,exang,oldpeak,slope,ca,thal,target,new_col
# 0,63,1,3,5,5,1,0,150,0,2.3,0,0,1,1,0.0
# 1,37,1,2,5,5,0,1,187,0,3.5,0,0,2,1,0.0
# 2,44,0,1,5,5,0,0,172,0,1.4,2,0,2,1,1.0
# 3,56,1,1,5,5,0,1,178,0,0.8,2,0,2,1,1.0
# 4,57,0,0,5,5,0,1,163,1,0.6,2,0,2,1,1.0
# 5,57,1,0,5,5,0,1,148,0,0.4,1,0,1,1,0.5
# 6,56,0,1,5,5,0,0,153,0,1.3,1,0,2,1,0.5
# 7,44,1,1,5,5,0,1,173,0,0.0,2,0,3,1,1.0
# 8,52,1,2,5,5,1,1,162,0,0.5,2,0,3,1,1.0
# 9,57,1,2,5,5,0,1,174,0,1.6,2,0,2,1,1.0
# 10,54,1,0,5,5,0,1,160,0,1.2,2,0,2,1,1.0
# 11,48,0,2,5,5,0,1,139,0,0.2,2,0,2,1,1.0
# 12,49,1,1,5,5,0,1,171,0,0.6,2,0,2,1,1.0
# 13,64,1,3,5,5,0,0,144,1,1.8,1,0,2,1,0.5
# 14,58,0,3,5,5,1,0,162,0,1.0,2,0,2,1,1.0
# 15,50,0,2,5,5,0,1,158,0,1.6,1,0,2,1,0.5
# 16,58,0,2,5,5,0,1,172,0,0.0,2,0,2,1,1.0
# 17,66,0,3,5,5,0,1,114,0,2.6,0,0,2,1,0.0
# 18,43,1,0,5,5,0,1,171,0,1.5,2,0,2,1,1.0
# 19,69,0,3,5,5,0,1,151,0,1.8,2,2,2,1,2.0
# 20,59,1,0,5,5,0,1,161,0,0.5,1,0,3,1,0.5
# ...

# %%
df
# Out:
#      Age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3         5     5    1        0      150      0      2.3
# 1     37    1   2         5     5    0        1      187      0      3.5
# 2     44    0   1         5     5    0        0      172      0      1.4
# 3     56    1   1         5     5    0        1      178      0      0.8
# 4     57    0   0         5     5    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0         5     5    0        1      123      1      0.2
# 299   45    1   3         5     5    0        1      132      0      1.2
# 300   68    1   0         5     5    1        1      141      0      3.4
# 301   57    1   0         5     5    0        1      115      1      1.2
# 302   57    0   1         5     5    0        0      174      0      0.0
#
#      slope  ca  thal  target  new_col
# 0        0   0     1       1      0.0
# ...

# %%
df.groupby
